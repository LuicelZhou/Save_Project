# %%
import pandas as pd

# %%
transaction = pd.read_csv('transactions.csv')

# %%
display(transaction)
# Out:
#       account_number transaction_datetime transaction_amount  post_date  \
# 0              26522    12182020 15:29:12              1.06-   12192020
# 1              26522    12302020 08:22:36              1.72-   12312020
# 2              11111    02192021 09:55:25           1009.90-    2202021
# 3              11111    02092021 11:15:52             14.00-    2112021
# 4              26522    01272021 09:34:44              0.90-    1272021
# ...              ...                  ...                ...        ...
# 2517           37222    02272021 15:27:57              4.85-    3012021
# 2518           37222    04012021 06:17:18             50.04-    4022021
# 2519           37222    03122021 07:33:49             45.73-    3132021
# 2520           37222    01212021 12:28:59            125.00-    1232021
# 2521           37222    02092021 11:15:52             14.00-    2112021
#
#       merchant_number                         merchant_description  \
# 0     000000000326552     MAVERIK #488           DRAPER       LAUS
# 1     900185000000000      HARMONS - BANGERTER    DRAPER        LA
# 2     527021002118976      CFA Institute          4349515499    TX
# 3     000225124800999      CHAPULTEPEC LUPITA     HOUSTON       TX
# 4     650000010604109      PCBC SPRINGVILLE       SPRINGVILLE   LA
# ...               ...                                          ...
# 2517  000000002355702  TIGER EXPRESS          Los Angeles       CA
# 2518  053894000053360              SHELL OIL  Los Angeles       CA
# 2519    4445025811745            SHELL OIL\t\tLos Angeles       CA
# 2520  000021668538000               SHELL OIL Los Angeles       CA
# 2521  000225124800999      CHAPULTEPEC LUPITA     Atlanta       GA
#
#       merchant_category_code  transaction_number
# 0                       5541                   3
# 1                       5411                   8
# 2                       8299                   1
# 3                       5812                   2
# 4                       5814                   2
# ...                      ...                 ...
# 2517                    5499                   2
# 2518                    5814                   3
# 2519                    5812                   4
# 2520                    5812                   5
# 2521                    5812                   6
#
# [2522 rows x 8 columns]

# %%
# split merchant_description into merchant_name and merchant_state
# keep last word as merchant_state, and the rest as merchant_name

transaction['merchant_name'] = transaction['merchant_description'].map(lambda x: ' '.join(x.split(" ")[:-1]))
transaction['merchant_state']= transaction['merchant_description'].map(lambda x: x.split(" ")[-1])

# %%
display(transaction)
# Out:
#       account_number transaction_datetime transaction_amount  post_date  \
# 0              26522    12182020 15:29:12              1.06-   12192020
# 1              26522    12302020 08:22:36              1.72-   12312020
# 2              11111    02192021 09:55:25           1009.90-    2202021
# 3              11111    02092021 11:15:52             14.00-    2112021
# 4              26522    01272021 09:34:44              0.90-    1272021
# ...              ...                  ...                ...        ...
# 2517           37222    02272021 15:27:57              4.85-    3012021
# 2518           37222    04012021 06:17:18             50.04-    4022021
# 2519           37222    03122021 07:33:49             45.73-    3132021
# 2520           37222    01212021 12:28:59            125.00-    1232021
# 2521           37222    02092021 11:15:52             14.00-    2112021
#
#       merchant_number                         merchant_description  \
# 0     000000000326552     MAVERIK #488           DRAPER       LAUS
# 1     900185000000000      HARMONS - BANGERTER    DRAPER        LA
# 2     527021002118976      CFA Institute          4349515499    TX
# 3     000225124800999      CHAPULTEPEC LUPITA     HOUSTON       TX
# 4     650000010604109      PCBC SPRINGVILLE       SPRINGVILLE   LA
# ...               ...                                          ...
# 2517  000000002355702  TIGER EXPRESS          Los Angeles       CA
# 2518  053894000053360              SHELL OIL  Los Angeles       CA
# 2519    4445025811745            SHELL OIL\t\tLos Angeles       CA
# 2520  000021668538000               SHELL OIL Los Angeles       CA
# 2521  000225124800999      CHAPULTEPEC LUPITA     Atlanta       GA
#
#       merchant_category_code  transaction_number  \
# 0                       5541                   3
# 1                       5411                   8
# 2                       8299                   1
# 3                       5812                   2
# 4                       5814                   2
# ...                      ...                 ...
# 2517                    5499                   2
# 2518                    5814                   3
# 2519                    5812                   4
# 2520                    5812                   5
# 2521                    5812                   6
#
#                                  merchant_name merchant_state
# 0          MAVERIK #488           DRAPER                 LAUS
# 1         HARMONS - BANGERTER    DRAPER                    LA
# 2         CFA Institute          4349515499                TX
# 3         CHAPULTEPEC LUPITA     HOUSTON                   TX
# 4         PCBC SPRINGVILLE       SPRINGVILLE               LA
# ...                                        ...            ...
# 2517  TIGER EXPRESS          Los Angeles                   CA
# 2518              SHELL OIL  Los Angeles                   CA
# 2519            SHELL OIL\t\tLos Angeles                   CA
# 2520               SHELL OIL Los Angeles                   CA
# 2521      CHAPULTEPEC LUPITA     Atlanta                   GA
#
# [2522 rows x 10 columns]

# %%
# map merchant_state to full state name
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

states_lists = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'
}

# %%
# take first two letters of merchant_state(ingnore US)
transaction['merchant_state'] = transaction['merchant_state'].map(lambda x: x[:2])

# %%
display(transaction)
# Out:
#       account_number transaction_datetime transaction_amount  post_date  \
# 0              26522    12182020 15:29:12              1.06-   12192020
# 1              26522    12302020 08:22:36              1.72-   12312020
# 2              11111    02192021 09:55:25           1009.90-    2202021
# 3              11111    02092021 11:15:52             14.00-    2112021
# 4              26522    01272021 09:34:44              0.90-    1272021
# ...              ...                  ...                ...        ...
# 2517           37222    02272021 15:27:57              4.85-    3012021
# 2518           37222    04012021 06:17:18             50.04-    4022021
# 2519           37222    03122021 07:33:49             45.73-    3132021
# 2520           37222    01212021 12:28:59            125.00-    1232021
# 2521           37222    02092021 11:15:52             14.00-    2112021
#
#       merchant_number                         merchant_description  \
# 0     000000000326552     MAVERIK #488           DRAPER       LAUS
# 1     900185000000000      HARMONS - BANGERTER    DRAPER        LA
# 2     527021002118976      CFA Institute          4349515499    TX
# 3     000225124800999      CHAPULTEPEC LUPITA     HOUSTON       TX
# 4     650000010604109      PCBC SPRINGVILLE       SPRINGVILLE   LA
# ...               ...                                          ...
# 2517  000000002355702  TIGER EXPRESS          Los Angeles       CA
# 2518  053894000053360              SHELL OIL  Los Angeles       CA
# 2519    4445025811745            SHELL OIL\t\tLos Angeles       CA
# 2520  000021668538000               SHELL OIL Los Angeles       CA
# 2521  000225124800999      CHAPULTEPEC LUPITA     Atlanta       GA
#
#       merchant_category_code  transaction_number  \
# 0                       5541                   3
# 1                       5411                   8
# 2                       8299                   1
# 3                       5812                   2
# 4                       5814                   2
# ...                      ...                 ...
# 2517                    5499                   2
# 2518                    5814                   3
# 2519                    5812                   4
# 2520                    5812                   5
# 2521                    5812                   6
#
#                                  merchant_name merchant_state
# 0          MAVERIK #488           DRAPER                   LA
# 1         HARMONS - BANGERTER    DRAPER                    LA
# 2         CFA Institute          4349515499                TX
# 3         CHAPULTEPEC LUPITA     HOUSTON                   TX
# 4         PCBC SPRINGVILLE       SPRINGVILLE               LA
# ...                                        ...            ...
# 2517  TIGER EXPRESS          Los Angeles                   CA
# 2518              SHELL OIL  Los Angeles                   CA
# 2519            SHELL OIL\t\tLos Angeles                   CA
# 2520               SHELL OIL Los Angeles                   CA
# 2521      CHAPULTEPEC LUPITA     Atlanta                   GA
#
# [2522 rows x 10 columns]

# %%
# delete merchant_description
# replace \t with space

del(transaction['merchant_description'])
transaction['merchant_name'] = transaction['merchant_name'].map(lambda x: x.replace('\t',' ') )

# %%
# mapping abbrevations with will state name
transaction['merchant_state'] = transaction['merchant_state'].map(lambda x: states_lists[x] if x in states else x)

# %%
transaction
# Out:
#       account_number transaction_datetime transaction_amount  post_date  \
# 0              26522    12182020 15:29:12              1.06-   12192020
# 1              26522    12302020 08:22:36              1.72-   12312020
# 2              11111    02192021 09:55:25           1009.90-    2202021
# 3              11111    02092021 11:15:52             14.00-    2112021
# 4              26522    01272021 09:34:44              0.90-    1272021
# ...              ...                  ...                ...        ...
# 2517           37222    02272021 15:27:57              4.85-    3012021
# 2518           37222    04012021 06:17:18             50.04-    4022021
# 2519           37222    03122021 07:33:49             45.73-    3132021
# 2520           37222    01212021 12:28:59            125.00-    1232021
# 2521           37222    02092021 11:15:52             14.00-    2112021
#
#       merchant_number  merchant_category_code  transaction_number  \
# 0     000000000326552                    5541                   3
# 1     900185000000000                    5411                   8
# 2     527021002118976                    8299                   1
# 3     000225124800999                    5812                   2
# 4     650000010604109                    5814                   2
# ...               ...                     ...                 ...
# 2517  000000002355702                    5499                   2
# 2518  053894000053360                    5814                   3
# 2519    4445025811745                    5812                   4
# 2520  000021668538000                    5812                   5
# 2521  000225124800999                    5812                   6
#
#                                  merchant_name merchant_state
# 0          MAVERIK #488           DRAPER            Louisiana
# 1         HARMONS - BANGERTER    DRAPER             Louisiana
# 2         CFA Institute          4349515499             Texas
# 3         CHAPULTEPEC LUPITA     HOUSTON                Texas
# 4         PCBC SPRINGVILLE       SPRINGVILLE        Louisiana
# ...                                        ...            ...
# 2517  TIGER EXPRESS          Los Angeles           California
# 2518              SHELL OIL  Los Angeles           California
# 2519              SHELL OIL  Los Angeles           California
# 2520               SHELL OIL Los Angeles           California
# 2521      CHAPULTEPEC LUPITA     Atlanta              Georgia
#
# [2522 rows x 9 columns]

# %%
transaction.to_csv('transaction_cleaned.csv', index=False)
